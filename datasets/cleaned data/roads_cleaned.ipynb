# %%
import pandas as pd

# %%
df = pd.read_csv('road.csv')
df
# Out:
#        latitude  longitude  altitude    geometry  \
# 0           NaN        NaN       NaN  LineString
# 1           NaN        NaN       NaN  LineString
# 2           NaN        NaN       NaN  LineString
# 3           NaN        NaN       NaN  LineString
# 4           NaN        NaN       NaN  LineString
# ...         ...        ...       ...         ...
# 28915       NaN        NaN       NaN  LineString
# 28916       NaN        NaN       NaN  LineString
# 28917       NaN        NaN       NaN  LineString
# 28918       NaN        NaN       NaN  LineString
# 28919       NaN        NaN       NaN  LineString
#
#                                              coordinates state_code source  \
# 0                 3.3759335,6.588558,3.3782292,6.5871543         LA   GRID
# 1      3.3018277,6.534834,3.2986712,6.5342047,3.29802...         LA   GRID
# 2      3.321723,6.4994495,3.321846,6.4997123,3.321962...         LA   GRID
# ...

# %%
df = df.drop(columns = ['latitude', 'longitude', 'altitude', 'geometry', 'state_code'])
df
# Out:
#                                              coordinates source  \
# 0                 3.3759335,6.588558,3.3782292,6.5871543   GRID
# 1      3.3018277,6.534834,3.2986712,6.5342047,3.29802...   GRID
# 2      3.321723,6.4994495,3.321846,6.4997123,3.321962...   GRID
# 3      3.9372436,6.5601682,3.9377545,6.5600534,3.9382...   GRID
# 4      3.5026881,6.4332293,3.5044775,6.4332422,3.5051...   GRID
# ...                                                  ...    ...
# 28915             3.5551467,6.438186,3.5549675,6.4374852   GRID
# 28916  3.2588469,6.6667396,3.2592183,6.6670698,3.2594...   GRID
# 28917            3.3196309,6.5160604,3.3195644,6.5160194   GRID
# 28918  3.4188956,6.4605016,3.4190978,6.4601757,3.4192...   GRID
# 28919  3.2517541,6.5734463,3.2524144,6.572968,3.25324...   GRID
#
#                                name surface_type smoothness one_way  \
# 0                Olorunfunmi Street       Tarred       Fair   False
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                                              coordinates source  \
# 0                 3.3759335,6.588558,3.3782292,6.5871543   GRID
# 1      3.3018277,6.534834,3.2986712,6.5342047,3.29802...   GRID
# 2      3.321723,6.4994495,3.321846,6.4997123,3.321962...   GRID
# 3      3.9372436,6.5601682,3.9377545,6.5600534,3.9382...   GRID
# 4      3.5026881,6.4332293,3.5044775,6.4332422,3.5051...   GRID
# ...                                                  ...    ...
# 28915             3.5551467,6.438186,3.5549675,6.4374852   GRID
# 28916  3.2588469,6.6667396,3.2592183,6.6670698,3.2594...   GRID
# 28917            3.3196309,6.5160604,3.3195644,6.5160194   GRID
# 28918  3.4188956,6.4605016,3.4190978,6.4601757,3.4192...   GRID
# 28919  3.2517541,6.5734463,3.2524144,6.572968,3.25324...   GRID
#
#                                name surface_type smoothness one_way  \
# 0                Olorunfunmi Street       Tarred       Fair   False
# ...

# %%
df = df.fillna('')
df
# Out:
#                                              coordinates source  \
# 0                 3.3759335,6.588558,3.3782292,6.5871543   GRID
# 1      3.3018277,6.534834,3.2986712,6.5342047,3.29802...   GRID
# 2      3.321723,6.4994495,3.321846,6.4997123,3.321962...   GRID
# 3      3.9372436,6.5601682,3.9377545,6.5600534,3.9382...   GRID
# 4      3.5026881,6.4332293,3.5044775,6.4332422,3.5051...   GRID
# ...                                                  ...    ...
# 28915             3.5551467,6.438186,3.5549675,6.4374852   GRID
# 28916  3.2588469,6.6667396,3.2592183,6.6670698,3.2594...   GRID
# 28917            3.3196309,6.5160604,3.3195644,6.5160194   GRID
# 28918  3.4188956,6.4605016,3.4190978,6.4601757,3.4192...   GRID
# 28919  3.2517541,6.5734463,3.2524144,6.572968,3.25324...   GRID
#
#                                name surface_type smoothness one_way  \
# 0                Olorunfunmi Street       Tarred       Fair   False
# ...

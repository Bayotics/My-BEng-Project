# %%
import pandas as pd

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
from sklearn.cluster import KMeans

# %%
from tabulate import tabulate

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('rent_lagos_updated.csv')
df
# Out:
#                         housing_type  bedrooms  bathrooms  guest_toilet  \
# 0                   flat / apartment         3          3             0
# 1                   flat / apartment         3          3             0
# 2                   flat / apartment         3          3             1
# 3                   flat / apartment         3          3             0
# 4                   flat / apartment         3          3             0
# ...                              ...       ...        ...           ...
# 20127  mini flat (room and parlour)          1          1             0
# 20128               flat / apartment         2          2             0
# 20129  mini flat (room and parlour)          1          1             0
# 20130               flat / apartment         2          2             0
# 20131               flat / apartment         3          3             1
#
#        parking_space    district  \
# 0                  3  ketu ikosi
# ...

# %%
for x in df.index:
    if df.loc[x, "bedrooms"] == 6:
        df.drop(x, inplace = True)
        
df
# Out:
#                         housing_type  bedrooms  bathrooms  guest_toilet  \
# 0                   flat / apartment         3          3             0
# 1                   flat / apartment         3          3             0
# 2                   flat / apartment         3          3             1
# 3                   flat / apartment         3          3             0
# 4                   flat / apartment         3          3             0
# ...                              ...       ...        ...           ...
# 20127  mini flat (room and parlour)          1          1             0
# 20128               flat / apartment         2          2             0
# 20129  mini flat (room and parlour)          1          1             0
# 20130               flat / apartment         2          2             0
# 20131               flat / apartment         3          3             1
#
#        parking_space    district  \
# 0                  3  ketu ikosi
# ...

# %%
for x in df.index:
    if df.loc[x, "bedrooms"] == 7:
        df.drop(x, inplace = True)
        
df
# Out:
#                         housing_type  bedrooms  bathrooms  guest_toilet  \
# 0                   flat / apartment         3          3             0
# 1                   flat / apartment         3          3             0
# 2                   flat / apartment         3          3             1
# 3                   flat / apartment         3          3             0
# 4                   flat / apartment         3          3             0
# ...                              ...       ...        ...           ...
# 20127  mini flat (room and parlour)          1          1             0
# 20128               flat / apartment         2          2             0
# 20129  mini flat (room and parlour)          1          1             0
# 20130               flat / apartment         2          2             0
# 20131               flat / apartment         3          3             1
#
#        parking_space    district  \
# 0                  3  ketu ikosi
# ...

# %%
for x in df.index:
    if df.loc[x, "bedrooms"] == 9:
        df.drop(x, inplace = True)
        
df
# Out:
#                         housing_type  bedrooms  bathrooms  guest_toilet  \
# 0                   flat / apartment         3          3             0
# 1                   flat / apartment         3          3             0
# 2                   flat / apartment         3          3             1
# 3                   flat / apartment         3          3             0
# 4                   flat / apartment         3          3             0
# ...                              ...       ...        ...           ...
# 20127  mini flat (room and parlour)          1          1             0
# 20128               flat / apartment         2          2             0
# 20129  mini flat (room and parlour)          1          1             0
# 20130               flat / apartment         2          2             0
# 20131               flat / apartment         3          3             1
#
#        parking_space    district  \
# 0                  3  ketu ikosi
# ...

# %%
#visualizing data using barplots

plt.figure(figsize=(80,25))
sns.set(style='white')

sns.barplot(x='district', y='rent_per_annum', hue='bedrooms', data=df)
# Out:
# <Axes: xlabel='district', ylabel='rent_per_annum'>

# %%
#visualizing data using boxplots
plt.figure(figsize=(80,25))

sns.boxplot(x="district", y="rent_per_annum",hue="bedrooms",data=df, palette="Set3")

plt.title("Boxplot of House rents")
plt.ylabel("Rent per annum")
plt.xlabel("District")

plt.show()

# %%
df = df.drop(columns = ['housing_type', 'bathrooms', 'guest_toilet', 'parking_space', 'address'])
df
# Out:
#        bedrooms    district  rent_per_annum  district_code local government
# 0             3  ketu ikosi     150000000.0             31           kosofe
# 1             3       ikoyi     600000000.0             25          eti osa
# 2             3     gbagada     350000000.0             13           kosofe
# 3             3       lekki     350000000.0             35          eti osa
# 4             3       lekki     350000000.0             35          eti osa
# ...         ...         ...             ...            ...              ...
# 20127         1     ikorodu        100000.0             23          ikorodu
# 20128         2       lekki        100000.0             35          eti osa
# 20129         1     ikorodu         90000.0             23          ikorodu
# 20130         2       ikoyi         90000.0             25          eti osa
# 20131         3       lekki         85000.0             35          eti osa
#
# [20121 rows x 5 columns]

# %%
#district codes

# %%
df = df.drop(columns = ['district', 'local government'])
df
# Out:
#        bedrooms  rent_per_annum  district_code
# 0             3     150000000.0             31
# 1             3     600000000.0             25
# 2             3     350000000.0             13
# 3             3     350000000.0             35
# 4             3     350000000.0             35
# ...         ...             ...            ...
# 20127         1        100000.0             23
# 20128         2        100000.0             35
# 20129         1         90000.0             23
# 20130         2         90000.0             25
# 20131         3         85000.0             35
#
# [20121 rows x 3 columns]

# %%
df
# Out:
#        bedrooms  rent_per_annum  district_code
# 0             3     150000000.0             31
# 1             3     600000000.0             25
# 2             3     350000000.0             13
# 3             3     350000000.0             35
# 4             3     350000000.0             35
# ...         ...             ...            ...
# 20127         1        100000.0             23
# 20128         2        100000.0             35
# 20129         1         90000.0             23
# 20130         2         90000.0             25
# 20131         3         85000.0             35
#
# [20121 rows x 3 columns]

# %%
df = df.replace(['ketu ojota'], '32')
df
# Out:
#        bedrooms  rent_per_annum  district_code
# 0             3     150000000.0             31
# 1             3     600000000.0             25
# 2             3     350000000.0             13
# 3             3     350000000.0             35
# 4             3     350000000.0             35
# ...         ...             ...            ...
# 20127         1        100000.0             23
# 20128         2        100000.0             35
# 20129         1         90000.0             23
# 20130         2         90000.0             25
# 20131         3         85000.0             35
#
# [20121 rows x 3 columns]

# %%
#K-Means clustering on cleaned data
k = 3
kmeans = KMeans(n_clusters = k, random_state=0).fit(df)
df['Cluster']=kmeans.labels_

# %%
fig, axes = plt.subplots(1, k, sharey=True)
axes[0].set_ylabel('Coded Values', fontsize=20)

for i in range(k):
     plt.sca(axes[i])
     plt.xticks(rotation=45,ha='right')
     sns.boxplot(palette="Set1",data = df[df['Cluster'] == i].drop('Cluster', axis=1), ax=axes[i]).tick_params(labelsize=8.5)
        
plt.show()

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 60)
    res = kmeans.fit(df)
    print(res)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# KMeans(n_clusters=1, random_state=60)
# KMeans(n_clusters=2, random_state=60)
# KMeans(n_clusters=3, random_state=60)
# KMeans(n_clusters=4, random_state=60)
# KMeans(n_clusters=5, random_state=60)
# KMeans(n_clusters=6, random_state=60)
# KMeans(n_clusters=7, random_state=60)
# KMeans(random_state=60)
# KMeans(n_clusters=9, random_state=60)
# KMeans(n_clusters=10, random_state=60)

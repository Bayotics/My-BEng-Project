# %%
import pandas as pd

# %%
df = pd.read_csv('rent.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#                   Price    Pid  \
# 0        400,000 / year  H1190
# 1     14,000,000 / year  G7398
# 2        200,000 / year  H5843
# 3        800,000 / year  H1194
# 4        300,000 / year  H5842
# ...                 ...    ...
# 9848     400,000 / year  F1443
# 9849            800,000  F1442
# 9850   1,000,000 / year  F1441
# 9851          1,500,000  F1433
# 9852          4,000,000  F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
df = df.rename(colunms = {'Pid': 'Property_id'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = df.rename(colunms = {'Pid': 'Property_id'})
#
# TypeError: DataFrame.rename() got an unexpected keyword argument 'colunms'

# %%
df = df.rename(column = {'Pid': 'Property_id'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = df.rename(column = {'Pid': 'Property_id'})
#
# TypeError: DataFrame.rename() got an unexpected keyword argument 'column'

# %%
df = df.rename(colunms = {'Pid': 'Property_id'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = df.rename(colunms = {'Pid': 'Property_id'})
#
# TypeError: DataFrame.rename() got an unexpected keyword argument 'colunms'

# %%
df
# Out:
#                   Price    Pid  \
# 0        400,000 / year  H1190
# 1     14,000,000 / year  G7398
# 2        200,000 / year  H5843
# 3        800,000 / year  H1194
# 4        300,000 / year  H5842
# ...                 ...    ...
# 9848     400,000 / year  F1443
# 9849            800,000  F1442
# 9850   1,000,000 / year  F1441
# 9851          1,500,000  F1433
# 9852          4,000,000  F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                   Price    Pid  \
# 0        400,000 / year  H1190
# 1     14,000,000 / year  G7398
# 2        200,000 / year  H5843
# 3        800,000 / year  H1194
# 4        300,000 / year  H5842
# ...                 ...    ...
# 9848     400,000 / year  F1443
# 9849            800,000  F1442
# 9850   1,000,000 / year  F1441
# 9851          1,500,000  F1433
# 9852          4,000,000  F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
df = df.rename(columns = {'Price' : 'Price_per_year', 'Pid' : 'Property_id'})
df
# Out:
#          Price_per_year Property_id  \
# 0        400,000 / year       H1190
# 1     14,000,000 / year       G7398
# 2        200,000 / year       H5843
# 3        800,000 / year       H1194
# 4        300,000 / year       H5842
# ...                 ...         ...
# 9848     400,000 / year       F1443
# 9849            800,000       F1442
# 9850   1,000,000 / year       F1441
# 9851          1,500,000       F1433
# 9852          4,000,000       F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# ...

# %%
df["Price_per_year"].str.strip()
# Out:
# 0          400,000 / year
# 1       14,000,000 / year
# 2          200,000 / year
# 3          800,000 / year
# 4          300,000 / year
#               ...
# 9848       400,000 / year
# 9849              800,000
# 9850     1,000,000 / year
# 9851            1,500,000
# 9852            4,000,000
# Name: Price_per_year, Length: 9850, dtype: object

# %%
df["Price_per_year"] = df["Price_per_year"].str.strip(" / year")
df
# Out:
#      Price_per_year Property_id  \
# 0           400,000       H1190
# 1        14,000,000       G7398
# 2           200,000       H5843
# 3           800,000       H1194
# 4           300,000       H5842
# ...             ...         ...
# 9848        400,000       F1443
# 9849        800,000       F1442
# 9850      1,000,000       F1441
# 9851      1,500,000       F1433
# 9852      4,000,000       F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
df["Price_per_year"] = df["Price_per_year"].str.strip("/ sqm")
df
# Out:
#      Price_per_year Property_id  \
# 0           400,000       H1190
# 1        14,000,000       G7398
# 2           200,000       H5843
# 3           800,000       H1194
# 4           300,000       H5842
# ...             ...         ...
# 9848        400,000       F1443
# 9849        800,000       F1442
# 9850      1,000,000       F1441
# 9851      1,500,000       F1433
# 9852      4,000,000       F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
df["Property_name"] = df["Property_name"].str.strip("/")
df
# Out:
#      Price_per_year Property_id  \
# 0           400,000       H1190
# 1        14,000,000       G7398
# 2           200,000       H5843
# 3           800,000       H1194
# 4           300,000       H5842
# ...             ...         ...
# 9848        400,000       F1443
# 9849        800,000       F1442
# 9850      1,000,000       F1441
# 9851      1,500,000       F1433
# 9852      4,000,000       F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
df["Property_name"].str.strip("/ Apartment")
# Out:
# 0       1 bedroom mini flat Flat / Apartment for rent ...
# 1       3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2       1 bedroom mini flat Flat / Apartment for rent ...
# 3       2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4       1 bedroom mini flat Flat / Apartment for rent ...
#                               ...
# 9848    1 bedroom mini flat Flat / Apartment for rent ...
# 9849    3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850    2 bedroom Flat / Apartment for rent Adekunle Y...
# 9851    3 bedroom Duplex for rent Off Chief Echegile S...
# 9852    8 bedroom Duplex for rent babs Animashuam Bode...
# Name: Property_name, Length: 9850, dtype: object

# %%
df
# Out:
#      Price_per_year Property_id  \
# 0           400,000       H1190
# 1        14,000,000       G7398
# 2           200,000       H5843
# 3           800,000       H1194
# 4           300,000       H5842
# ...             ...         ...
# 9848        400,000       F1443
# 9849        800,000       F1442
# 9850      1,000,000       F1441
# 9851      1,500,000       F1433
# 9852      4,000,000       F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('churches.csv')

# %%
df
# Out:
#       latitude  longitude  altitude geometry state_code source  \
# 0      6.57943    3.34186       NaN    Point         LA  OSGOF
# 1      6.44097    3.14695       NaN    Point         LA  OSGOF
# 2      6.43489    3.48553       NaN    Point         LA  OSGOF
# 3      6.55730    3.34714       NaN    Point         LA  OSGOF
# 4      6.61136    3.39815       NaN    Point         LA  OSGOF
# ...        ...        ...       ...      ...        ...    ...
# 1410   6.61538    3.89352       NaN    Point         LA  OSGOF
# 1411   6.47952    3.33497       NaN    Point         LA  OSGOF
# 1412   6.45538    3.35029       NaN    Point         LA  OSGOF
# 1413   6.54799    3.39303       NaN    Point         LA  OSGOF
# 1414   6.60435    3.40195       NaN    Point         LA  OSGOF
#
#                                                    name ward_code poi_type  \
# 0                      Gospel Apostolic Church Shogunle  LASOIO20   Church
# ...

# %%
df = df.drop(columns = ['altitude'])
df
# Out:
#       latitude  longitude source  \
# 0      6.57943    3.34186  OSGOF
# 1      6.44097    3.14695  OSGOF
# 2      6.43489    3.48553  OSGOF
# 3      6.55730    3.34714  OSGOF
# 4      6.61136    3.39815  OSGOF
# ...        ...        ...    ...
# 1410   6.61538    3.89352  OSGOF
# 1411   6.47952    3.33497  OSGOF
# 1412   6.45538    3.35029  OSGOF
# 1413   6.54799    3.39303  OSGOF
# 1414   6.60435    3.40195  OSGOF
#
#                                                    name ward_code  \
# 0                      Gospel Apostolic Church Shogunle  LASOIO20
# 1        S And C Church Of God Church Ese Ofin Riverine  LASOJO02
# 2                Redeemed Christian Church Of God Ikate  LASEOA10
# 3       Redeemed Christian Church Of God 1 Igbehin Adun  LASOIO11
# 4                       Deeper Life Bible Church Maidan  LASKSE20
# ...                                                 ...       ...
# 1410                  St Peter's Anglican Church Ejirin  LASEPE07
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('mosques.csv')

# %%
df
# Out:
#      latitude  longitude  altitude geometry state_code source  \
# 0     6.58163    3.34090       NaN    Point         LA  OSGOF
# 1     6.46541    3.33473       NaN    Point         LA  OSGOF
# 2     6.41676    3.31395       NaN    Point         LA  OSGOF
# 3     6.54389    3.37999       NaN    Point         LA  OSGOF
# 4     6.40346    3.09423       NaN    Point         LA  OSGOF
# ..        ...        ...       ...      ...        ...    ...
# 561   6.61847    3.32078       NaN    Point         LA  OSGOF
# 562   6.60655    3.29418       NaN    Point         LA  OSGOF
# 563   6.47157    3.18974       NaN    Point         LA  OSGOF
# 564   6.53683    3.35343       NaN    Point         LA  OSGOF
# 565   6.46285    3.16857       NaN    Point         LA  OSGOF
#
#                                name ward_code poi_type  \
# 0               Ikawo Kolaso Mosque  LASOIO20   Mosque
# 1             Ifelodun Mosque Alaba  LASATO06   Mosque
# ...

# %%
df.drop(columns = ['altitude', 'geometry', 'state_code', 'poi_type'])
# Out:
#      latitude  longitude source                            name ward_code  \
# 0     6.58163    3.34090  OSGOF             Ikawo Kolaso Mosque  LASOIO20
# 1     6.46541    3.33473  OSGOF           Ifelodun Mosque Alaba  LASATO06
# 2     6.41676    3.31395  OSGOF         Igbo Isu Central Mosque  LASAON09
# 3     6.54389    3.37999  OSGOF      Maharufdeen Central Mosque  LASSMU06
# 4     6.40346    3.09423  OSGOF     Igbo Oja Nla Central Mosque  LASOJO15
# ..        ...        ...    ...                             ...       ...
# 561   6.61847    3.32078  OSGOF                 Ahmadiya Mosque  LASAGG02
# 562   6.60655    3.29418  OSGOF       Ike Oluwa Mosque Alimosho  LASAMO10
# 563   6.47157    3.18974  OSGOF       Okokomaiko Central Mosque  LASOJO12
# 564   6.53683    3.35343  OSGOF       Olorunsogo Central Mosque  LASMUN12
# 565   6.46285    3.16857  OSGOF  Ajangbadi Hausa Central Mosque  LASOJO07
#
#                                 global_id
# ...
